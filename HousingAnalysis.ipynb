# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Use Pandas to read the Train CSV
house_data = pd.read_csv("../train.csv")
house_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# Compare sale price to the year the house was remodeled
sale_price = house_data["SalePrice"]
remodeled = house_data["YearRemodAdd"]

plt.scatter(remodeled, sale_price)
plt.show()

# %%
# Identify the types of zones possible
zones = remodeled = house_data["MSZoning"].unique()
zones
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
# Filter the sale price data by each of the zoning types
zoneRL = house_data.loc[(house_data["MSZoning"]=="RL")]["SalePrice"]
zoneRM = house_data.loc[(house_data["MSZoning"]=="RM")]["SalePrice"]
zoneC = house_data.loc[(house_data["MSZoning"]=="C (all)")]["SalePrice"]
zoneFV = house_data.loc[(house_data["MSZoning"]=="FV")]["SalePrice"]
zoneRH = house_data.loc[(house_data["MSZoning"]=="RH")]["SalePrice"]

# %%
# Generate a box plot of the each of the zoning types
plot_data = [zoneRL, zoneRM, zoneC, zoneFV, zoneRH]
fig = plt.figure(1, figsize=(9, 6))
ax = fig.add_subplot(111)
ax.boxplot(plot_data)
ax.set_xticklabels(zones, fontsize=14)
plt.ylabel("Sale Price", fontsize=14, labelpad=12)
plt.yticks(fontsize=14)
plt.show()

# %%
encoded = pd.get_dummies(data=house_data, columns=['MSSubClass',
'MSZoning',
'Street',
'Alley',
'LotShape',
'LandContour',
'Utilities',
'LotConfig',
'LandSlope',
'Neighborhood',
'Condition1',
'Condition2',
'BldgType',
'HouseStyle',
'RoofStyle',
'RoofMatl',
'Exterior1st',
'Exterior2nd',
'MasVnrType',
'ExterQual',
'ExterCond',
'Foundation',
'BsmtQual',
'BsmtCond',
'BsmtExposure',
'BsmtFinType1',
'BsmtFinType2',
'Heating',
'HeatingQC',
'CentralAir',
'Electrical',
'KitchenQual',
'Functional',
'FireplaceQu',
'GarageType',
'GarageFinish',
'GarageQual',
'GarageCond',
'PavedDrive',
'PoolQC',
'Fence',
'MiscFeature',
'MoSold',
'SaleType',
'SaleCondition'])
encoded
# Out:
#         Id  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        1         65.0     8450            7            5       2003
# 1        2         80.0     9600            6            8       1976
# 2        3         68.0    11250            7            5       2001
# 3        4         60.0     9550            7            5       1915
# 4        5         84.0    14260            8            5       2000
# ...    ...          ...      ...          ...          ...        ...
# 1455  1456         62.0     7917            6            5       1999
# 1456  1457         85.0    13175            6            6       1978
# 1457  1458         66.0     9042            7            9       1941
# 1458  1459         68.0     9717            5            6       1950
# 1459  1460         75.0     9937            5            6       1965
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  SaleType_ConLw  \
# ...

# %%
correlations = encoded.corr()
correlations
# Out:
#                              Id  LotFrontage   LotArea  OverallQual  \
# Id                     1.000000    -0.010601 -0.033226    -0.028365
# LotFrontage           -0.010601     1.000000  0.426095     0.251646
# LotArea               -0.033226     0.426095  1.000000     0.105806
# OverallQual           -0.028365     0.251646  0.105806     1.000000
# OverallCond            0.012609    -0.059213 -0.005636    -0.091932
# ...                         ...          ...       ...          ...
# SaleCondition_AdjLand -0.034852    -0.037030 -0.013208    -0.041677
# SaleCondition_Alloca  -0.009018    -0.019817  0.008966    -0.044950
# SaleCondition_Family   0.004865     0.016684 -0.010781    -0.025515
# SaleCondition_Normal   0.015881    -0.076258  0.005711    -0.143282
# SaleCondition_Partial -0.020738     0.126571  0.022635     0.323295
#
#                        OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  \
# Id                        0.012609  -0.012713     -0.021998   -0.050298
# ...

# %%
highest_corr = correlations.loc[(correlations["SalePrice"]>.6) | (correlations["SalePrice"]<-.6)]["SalePrice"]
highest_corr
# Out:
# OverallQual    0.790982
# TotalBsmtSF    0.613581
# 1stFlrSF       0.605852
# GrLivArea      0.708624
# GarageCars     0.640409
# GarageArea     0.623431
# SalePrice      1.000000
# Name: SalePrice, dtype: float64
